# %%
import os

ROOT = "image"
KERNEL_SIZE = 640
STRIDE = 320
image_list_file = []
image_category = os.listdir(ROOT)

for category in image_category:
    image_lists = os.listdir("%s/%s" % (ROOT, category))
    
    for image in image_lists:
        if image.endswith(".txt"): continue
        image_list_file.append("%s/%s/%s" % (ROOT, category, image))

image_list_file.sort()

# %%
from ultralytics import YOLO

detector = YOLO("weights/epoch250.pt")

LABEL_LIST = detector.names

# %%
import cv2
import matplotlib.pyplot as plt

plt.imshow(cv2.imread(image_list_file[0]))
plt.show()

# %%
def sliding(image, kernel_size=640, stride=10):
    result = []
    for y in range(0, image.shape[0], stride):
        temp_image = image[y : y + kernel_size]
        rows_image = []
        
        for x in range(0, image.shape[1], stride):
            cropped = temp_image[:, x : x + kernel_size]
            rows_image.append(cropped)
            
            if cropped.shape[1] < KERNEL_SIZE: break
        
        result.append(rows_image)
        
        if temp_image.shape[0] < KERNEL_SIZE: break
    
    return result

# %%
# slided_image = sliding(image_list[0], KERNEL_SIZE, STRIDE)
# row = len(slided_image)
# col = len(slided_image[0])

# plt.figure(figsize=(100, 100))

# for i, row_data in enumerate(slided_image):
#     for j, image in enumerate(row_data):
#         plt.subplot(row, col, i * row + j + 1)
#         plt.imshow(image)

# plt.show()

# %%
# plt.imshow(slided_image[1][10])
# plt.show()

# %%
import threading
import time
import multiprocessing

class detectData():
    def __init__(self):
        self.x1 = 0
        self.x2 = 0
        self.y1 = 0
        self.y2 = 0
        self.cls = 0
        self.conf = 0

class PriorityQueue():
    def __init__(self):
        self.data = []
    
    def add(self, data):
        self.data.append(data)
        self.data.sort(key=lambda d: d.conf)
    
    def size(self):
        return len(self.data)
    
    def get(self, i):
        return self.data[i]
    
    def clear(self):
        self.data = []
    
    def to_array(self):
        return self.data

def overlap(x1, y1, x2, y2):
    l1 = x1 - y1 / 2
    l2 = x2 - y2 / 2
    left = l1 if l1 > l2 else l2
    
    r1 = x1 + y1 / 2
    r2 = x2 + y2 / 2
    right = r1 if r1 < r2 else r2
    
    return right - left

def box_intersection(a, b):
    w = overlap((a.x1 + a.x2) / 2, (a.x2 - a.x1),
                (b.x1 + b.x2) / 2, (b.x2 - b.x1))
                
    h = overlap((a.y1 + a.y2) / 2, (a.y2 - a.y1),
                (b.y1 + b.y2) / 2, (b.y2 - b.y1))
    
    if (w < 0 or h < 0): return 0
    
    return  w * h

def box_union(a, b):
    i = box_intersection(a, b)
    u = (a.x2 - a.x1) * (a.y2 - a.y1) + (b.x2 - b.x1) * (b.y2 - b.y1) - i
    return u

def box_iou(a, b):
    return box_intersection(a, b) / box_union(a, b)
    
def nms(detect_list):
    pq = PriorityQueue()
    nmsList = []
    
    pq = PriorityQueue()
        
    for i, detect in enumerate(detect_list):
        pq.add(detect)

    while pq.size() > 0:
        detections = pq.to_array()
        max = detections[-1]
        nmsList.append(max)
        pq.clear()

        for j, detection in enumerate(detections):
            if box_iou(max, detection) < 0.125:
                pq.add(detection)
    
    return nmsList

def detect_postprocessing(detections, stride):
    boxes = []
    
    spend = time.time()
    
    for i, detect_row in enumerate(detections):
        for j, detect in enumerate(detect_row):
            boxes_orig = detect.boxes.cpu().numpy()

            for box_list in boxes_orig:
                for box in box_list:
                    nbox = detectData()

                    x1, y1, x2, y2 = box.xyxy[0]

                    nbox.x1 = int(x1 + (j * stride))
                    nbox.x2 = int(x2 + (j * stride))
                    nbox.y1 = int(y1 + (i * stride))
                    nbox.y2 = int(y2 + (i * stride))
                    nbox.cls = int(box.cls[0])
                    nbox.conf = box.conf[0]
                    
                    boxes.append(nbox)
    
    print("spend: %fs | " % (time.time() - spend), end="")
    
    return boxes

def detectCrack(images_file):
    detections_final = []
    spend_time = 0
    cycles = 1
    
    def detect_processing(slided, stride):
        detection = []
        
        for image_row in slided:
            detection.append(detector(image_row, conf=0.50, verbose=False))
            
        postprocessed = detect_postprocessing(detection, stride)
        
        return postprocessed
    
    class saveImage(threading.Thread):
        def __init__(self, path, image):
            super().__init__()
            self.path = path
            self.image = image

        def run(self):
            cv2.imwrite(self.path, self.image)
    
    for i, image_file in enumerate(images_file):
        image = cv2.imread(image_file)
        #image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        
        start_time = time.time()
        
        detect_spend = time.time()
        #postprocessed_1 = detect_processing(sliding(image, KERNEL_SIZE // 4, STRIDE // 4), STRIDE // 4)
        postprocessed_3 = detect_processing(sliding(image, KERNEL_SIZE, STRIDE), STRIDE)
        postprocessed_4 = detect_processing(sliding(image, KERNEL_SIZE * 2, STRIDE * 2), STRIDE * 2)
        
        detect_spend = time.time() - detect_spend
        
        nms_spend = time.time()
        boxes = nms(postprocessed_3 + postprocessed_4)
        nms_spend = time.time() - nms_spend
    
        for box in boxes:
            cv2.putText(image, "%s %f%%" % (LABEL_LIST[box.cls], box.conf), (box.x1, box.y1-10), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255))
            cv2.rectangle(image, (box.x1, box.y1), (box.x2, box.y2), (0, 0, 255), 3)
            
        saveImage("detect/image-%d.png" % (i), image).start()
        
        spend_time += time.time() - start_time
        
        print("Complete: %d | avg spend_time: %fs | detect: %fs | nms: %fs" % (i, spend_time / cycles, detect_spend, nms_spend))
        cycles += 1
    
    return None

# %%
detections_result = detectCrack(image_list_file)
# Out:
# spend: 0.023485s | spend: 0.005401s | Complete: 0 | avg spend_time: 11.948686s | detect: 11.936663s | nms: 0.009822s
# spend: 0.023819s | spend: 0.005599s | Complete: 1 | avg spend_time: 10.136317s | detect: 8.304097s | nms: 0.017396s
# spend: 0.023972s | spend: 0.005440s | Complete: 2 | avg spend_time: 9.528677s | detect: 8.297705s | nms: 0.013326s
# spend: 0.023301s | spend: 0.005570s | Complete: 3 | avg spend_time: 9.220578s | detect: 8.275391s | nms: 0.018371s
# spend: 0.024021s | spend: 0.005556s | Complete: 4 | avg spend_time: 9.041259s | detect: 8.298504s | nms: 0.022775s
# spend: 0.023327s | spend: 0.005726s | Complete: 5 | avg spend_time: 8.921848s | detect: 8.307763s | nms: 0.014616s
# spend: 0.024570s | spend: 0.005443s | Complete: 6 | avg spend_time: 8.834624s | detect: 8.296368s | nms: 0.012685s
# spend: 0.023178s | spend: 0.005412s | Complete: 7 | avg spend_time: 8.768641s | detect: 8.293109s | nms: 0.011484s
# spend: 0.023744s | spend: 0.005687s | Complete: 8 | avg spend_time: 8.719566s | detect: 8.303569s | nms: 0.020644s
# spend: 0.023482s | spend: 0.005671s | Complete: 9 | avg spend_time: 8.679693s | detect: 8.303891s | nms: 0.014493s
# spend: 0.023815s | spend: 0.005406s | Complete: 10 | avg spend_time: 8.645599s | detect: 8.288956s | nms: 0.013450s
# spend: 0.023280s | spend: 0.005631s | Complete: 11 | avg spend_time: 8.628380s | detect: 8.422427s | nms: 0.014064s
# spend: 0.023223s | spend: 0.005643s | Complete: 12 | avg spend_time: 8.603107s | detect: 8.287018s | nms: 0.010548s
# spend: 0.023049s | spend: 0.005615s | Complete: 13 | avg spend_time: 8.582202s | detect: 8.297754s | nms: 0.010228s
# spend: 0.024270s | spend: 0.006083s | Complete: 14 | avg spend_time: 8.564685s | detect: 8.292860s | nms: 0.023833s
# spend: 0.023068s | spend: 0.005711s | Complete: 15 | avg spend_time: 8.547558s | detect: 8.277916s | nms: 0.010730s
# spend: 0.023412s | spend: 0.005603s | Complete: 16 | avg spend_time: 8.532650s | detect: 8.276892s | nms: 0.014853s
# spend: 0.024348s | spend: 0.005713s | Complete: 17 | avg spend_time: 8.522764s | detect: 8.336537s | nms: 0.015720s
# spend: 0.024029s | spend: 0.005728s | Complete: 18 | avg spend_time: 8.510815s | detect: 8.279386s | nms: 0.013977s
# spend: 0.023674s | spend: 0.005943s | Complete: 19 | avg spend_time: 8.500189s | detect: 8.279278s | nms: 0.016524s
# spend: 0.023362s | spend: 0.005732s | Complete: 20 | avg spend_time: 8.489574s | detect: 8.265102s | nms: 0.010098s
# spend: 0.024213s | spend: 0.005654s | Complete: 21 | avg spend_time: 8.482182s | detect: 8.296714s | nms: 0.027466s
# spend: 0.023065s | spend: 0.005662s | Complete: 22 | avg spend_time: 8.473487s | detect: 8.270700s | nms: 0.009487s
# spend: 0.022733s | spend: 0.005866s | Complete: 23 | avg spend_time: 8.465802s | detect: 8.272820s | nms: 0.013813s
# spend: 0.023144s | spend: 0.005556s | Complete: 24 | avg spend_time: 8.458815s | detect: 8.277897s | nms: 0.011034s
# spend: 0.023672s | spend: 0.005782s | Complete: 25 | avg spend_time: 8.453302s | detect: 8.293838s | nms: 0.019110s
# spend: 0.024662s | spend: 0.005556s | Complete: 26 | avg spend_time: 8.450996s | detect: 8.369369s | nms: 0.019061s
# spend: 0.023322s | spend: 0.005473s | Complete: 27 | avg spend_time: 8.444818s | detect: 8.265450s | nms: 0.010187s
# spend: 0.024429s | spend: 0.005979s | Complete: 28 | avg spend_time: 8.440922s | detect: 8.295421s | nms: 0.033266s
# spend: 0.023917s | spend: 0.005842s | Complete: 29 | avg spend_time: 8.436495s | detect: 8.292953s | nms: 0.012841s
# spend: 0.023566s | spend: 0.005940s | Complete: 30 | avg spend_time: 8.432342s | detect: 8.290071s | nms: 0.014994s
# spend: 0.023515s | spend: 0.005858s | Complete: 31 | avg spend_time: 8.428169s | detect: 8.281386s | nms: 0.014975s
# spend: 0.023540s | spend: 0.005929s | Complete: 32 | avg spend_time: 8.424167s | detect: 8.280189s | nms: 0.013465s
# spend: 0.023270s | spend: 0.005996s | Complete: 33 | avg spend_time: 8.420673s | detect: 8.288055s | nms: 0.014653s
# spend: 0.023456s | spend: 0.005975s | Complete: 34 | avg spend_time: 8.417500s | detect: 8.290684s | nms: 0.016212s
# spend: 0.023004s | spend: 0.006441s | Complete: 35 | avg spend_time: 8.414111s | detect: 8.277821s | nms: 0.015014s
# spend: 0.023875s | spend: 0.006316s | Complete: 36 | avg spend_time: 8.411282s | detect: 8.286771s | nms: 0.019869s
# spend: 0.023832s | spend: 0.006294s | Complete: 37 | avg spend_time: 8.409241s | detect: 8.310839s | nms: 0.020187s
# spend: 0.023888s | spend: 0.006109s | Complete: 38 | avg spend_time: 8.406935s | detect: 8.296859s | nms: 0.019835s
# spend: 0.024005s | spend: 0.006149s | Complete: 39 | avg spend_time: 8.404357s | detect: 8.286403s | nms: 0.014817s
# spend: 0.023243s | spend: 0.006291s | Complete: 40 | avg spend_time: 8.404662s | detect: 8.400490s | nms: 0.013906s
# spend: 0.023689s | spend: 0.005903s | Complete: 41 | avg spend_time: 8.402461s | detect: 8.292960s | nms: 0.016870s
# spend: 0.023359s | spend: 0.005913s | Complete: 42 | avg spend_time: 8.399993s | detect: 8.282313s | nms: 0.011700s
# spend: 0.022902s | spend: 0.006232s | Complete: 43 | avg spend_time: 8.397615s | detect: 8.283290s | nms: 0.009771s
# spend: 0.024390s | spend: 0.006085s | Complete: 44 | avg spend_time: 8.395956s | detect: 8.294849s | nms: 0.025059s
# spend: 0.022881s | spend: 0.005870s | Complete: 45 | avg spend_time: 8.393943s | detect: 8.290495s | nms: 0.010502s
# spend: 0.022968s | spend: 0.005851s | Complete: 46 | avg spend_time: 8.391738s | detect: 8.279573s | nms: 0.008638s
# spend: 0.023375s | spend: 0.006354s | Complete: 47 | avg spend_time: 8.389963s | detect: 8.287541s | nms: 0.016058s
# spend: 0.022635s | spend: 0.005535s | Complete: 48 | avg spend_time: 8.387732s | detect: 8.271302s | nms: 0.007404s
# spend: 0.022869s | spend: 0.005902s | Complete: 49 | avg spend_time: 8.385934s | detect: 8.288548s | nms: 0.007277s
# spend: 0.022518s | spend: 0.006057s | Complete: 50 | avg spend_time: 8.384013s | detect: 8.276701s | nms: 0.008903s
# spend: 0.024504s | spend: 0.005810s | Complete: 51 | avg spend_time: 8.382937s | detect: 8.297125s | nms: 0.027913s
# spend: 0.024214s | spend: 0.005886s | Complete: 52 | avg spend_time: 8.381624s | detect: 8.288491s | nms: 0.022002s
# spend: 0.024651s | spend: 0.005914s | Complete: 53 | avg spend_time: 8.380437s | detect: 8.279614s | nms: 0.034366s
# spend: 0.023597s | spend: 0.006118s | Complete: 54 | avg spend_time: 8.378833s | detect: 8.273695s | nms: 0.015881s
# spend: 0.023536s | spend: 0.005821s | Complete: 55 | avg spend_time: 8.379148s | detect: 8.379753s | nms: 0.014311s
# spend: 0.023139s | spend: 0.006198s | Complete: 56 | avg spend_time: 8.377671s | detect: 8.283297s | nms: 0.009311s
# spend: 0.023178s | spend: 0.006048s | Complete: 57 | avg spend_time: 8.376496s | detect: 8.293657s | nms: 0.013341s
# spend: 0.022970s | spend: 0.006312s | Complete: 58 | avg spend_time: 8.375344s | detect: 8.294668s | nms: 0.011410s
# spend: 0.022731s | spend: 0.005992s | Complete: 59 | avg spend_time: 8.373915s | detect: 8.279002s | nms: 0.008238s
# spend: 0.023271s | spend: 0.005750s | Complete: 60 | avg spend_time: 8.372669s | detect: 8.282228s | nms: 0.013186s
# spend: 0.023675s | spend: 0.006175s | Complete: 61 | avg spend_time: 8.371926s | detect: 8.302511s | nms: 0.021289s
# spend: 0.022806s | spend: 0.006104s | Complete: 62 | avg spend_time: 8.370767s | detect: 8.288156s | nms: 0.008488s
# spend: 0.023675s | spend: 0.005929s | Complete: 63 | avg spend_time: 8.369830s | detect: 8.296912s | nms: 0.011478s
# spend: 0.024210s | spend: 0.006067s | Complete: 64 | avg spend_time: 8.369061s | detect: 8.295563s | nms: 0.021621s
# spend: 0.023889s | spend: 0.005811s | Complete: 65 | avg spend_time: 8.368272s | detect: 8.296976s | nms: 0.017502s
# spend: 0.023252s | spend: 0.005686s | Complete: 66 | avg spend_time: 8.367192s | detect: 8.283326s | nms: 0.010438s
# spend: 0.023268s | spend: 0.006234s | Complete: 67 | avg spend_time: 8.366239s | detect: 8.284540s | nms: 0.015390s
# spend: 0.024128s | spend: 0.006041s | Complete: 68 | avg spend_time: 8.365410s | detect: 8.292931s | nms: 0.013642s
# spend: 0.023596s | spend: 0.006373s | Complete: 69 | avg spend_time: 8.364867s | detect: 8.305504s | nms: 0.018962s
# spend: 0.023116s | spend: 0.006052s | Complete: 70 | avg spend_time: 8.365417s | detect: 8.391025s | nms: 0.010237s
# spend: 0.024246s | spend: 0.006016s | Complete: 71 | avg spend_time: 8.364743s | detect: 8.293063s | nms: 0.021039s
# spend: 0.023741s | spend: 0.005747s | Complete: 72 | avg spend_time: 8.363760s | detect: 8.276621s | nms: 0.013921s
# spend: 0.023748s | spend: 0.005638s | Complete: 73 | avg spend_time: 8.362983s | detect: 8.288386s | nms: 0.015423s
# spend: 0.024351s | spend: 0.005925s | Complete: 74 | avg spend_time: 8.362443s | detect: 8.294007s | nms: 0.025264s
# spend: 0.023840s | spend: 0.006011s | Complete: 75 | avg spend_time: 8.361719s | detect: 8.287924s | nms: 0.016891s
# spend: 0.023880s | spend: 0.005913s | Complete: 76 | avg spend_time: 8.360382s | detect: 8.243412s | nms: 0.012881s
# spend: 0.023027s | spend: 0.005746s | Complete: 77 | avg spend_time: 8.359066s | detect: 8.246741s | nms: 0.008820s
# spend: 0.023942s | spend: 0.006379s | Complete: 78 | avg spend_time: 8.358093s | detect: 8.251308s | nms: 0.027923s
# spend: 0.023688s | spend: 0.006316s | Complete: 79 | avg spend_time: 8.357079s | detect: 8.254977s | nms: 0.019352s
# spend: 0.023752s | spend: 0.006351s | Complete: 80 | avg spend_time: 8.356115s | detect: 8.258183s | nms: 0.018161s
# spend: 0.024407s | spend: 0.006138s | Complete: 81 | avg spend_time: 8.355299s | detect: 8.266733s | nms: 0.019670s
# spend: 0.022733s | spend: 0.006189s | Complete: 82 | avg spend_time: 8.354155s | detect: 8.243875s | nms: 0.013892s
# spend: 0.023440s | spend: 0.006154s | Complete: 83 | avg spend_time: 8.353126s | detect: 8.250985s | nms: 0.014319s
# spend: 0.023257s | spend: 0.006297s | Complete: 84 | avg spend_time: 8.353545s | detect: 8.371048s | nms: 0.015121s
# spend: 0.024121s | spend: 0.006044s | Complete: 85 | avg spend_time: 8.352735s | detect: 8.263289s | nms: 0.017949s
# spend: 0.023644s | spend: 0.006097s | Complete: 86 | avg spend_time: 8.351666s | detect: 8.244632s | nms: 0.012779s
# spend: 0.022366s | spend: 0.005711s | Complete: 87 | avg spend_time: 8.350272s | detect: 8.221646s | nms: 0.005319s
# spend: 0.023254s | spend: 0.005800s | Complete: 88 | avg spend_time: 8.349089s | detect: 8.232020s | nms: 0.010707s
# spend: 0.023669s | spend: 0.006314s | Complete: 89 | avg spend_time: 8.348203s | detect: 8.242012s | nms: 0.024240s
# spend: 0.023682s | spend: 0.006612s | Complete: 90 | avg spend_time: 8.347273s | detect: 8.248480s | nms: 0.012492s
# spend: 0.023157s | spend: 0.005847s | Complete: 91 | avg spend_time: 8.346264s | detect: 8.236895s | nms: 0.014653s
# spend: 0.024054s | spend: 0.006111s | Complete: 92 | avg spend_time: 8.345486s | detect: 8.244947s | nms: 0.025853s
# spend: 0.022389s | spend: 0.005936s | Complete: 93 | avg spend_time: 8.344340s | detect: 8.228979s | nms: 0.006721s
# spend: 0.023401s | spend: 0.006202s | Complete: 94 | avg spend_time: 8.343658s | detect: 8.255958s | nms: 0.020688s
# spend: 0.023450s | spend: 0.006039s | Complete: 95 | avg spend_time: 8.342617s | detect: 8.232946s | nms: 0.008692s
# spend: 0.023896s | spend: 0.005965s | Complete: 96 | avg spend_time: 8.341908s | detect: 8.253058s | nms: 0.018076s
# spend: 0.023056s | spend: 0.006255s | Complete: 97 | avg spend_time: 8.341027s | detect: 8.242461s | nms: 0.010693s
# spend: 0.022530s | spend: 0.006222s | Complete: 98 | avg spend_time: 8.340047s | detect: 8.234291s | nms: 0.007550s
# spend: 0.023420s | spend: 0.005912s | Complete: 99 | avg spend_time: 8.340149s | detect: 8.335365s | nms: 0.012583s
# spend: 0.023551s | spend: 0.006042s | Complete: 100 | avg spend_time: 8.339333s | detect: 8.237884s | nms: 0.017189s
# spend: 0.023660s | spend: 0.006039s | Complete: 101 | avg spend_time: 8.338599s | detect: 8.240544s | nms: 0.021023s
# spend: 0.023267s | spend: 0.007142s | Complete: 102 | avg spend_time: 8.337677s | detect: 8.222015s | nms: 0.018859s
# spend: 0.023793s | spend: 0.006399s | Complete: 103 | avg spend_time: 8.336953s | detect: 8.238476s | nms: 0.021228s
# spend: 0.022976s | spend: 0.006196s | Complete: 104 | avg spend_time: 8.335845s | detect: 8.209558s | nms: 0.008788s
# spend: 0.023739s | spend: 0.005911s | Complete: 105 | avg spend_time: 8.335078s | detect: 8.234548s | nms: 0.017219s
# spend: 0.023687s | spend: 0.005620s | Complete: 106 | avg spend_time: 8.334218s | detect: 8.225965s | nms: 0.014826s
# spend: 0.023748s | spend: 0.006172s | Complete: 107 | avg spend_time: 8.333476s | detect: 8.231462s | nms: 0.019834s
# spend: 0.024761s | spend: 0.006023s | Complete: 108 | avg spend_time: 8.332974s | detect: 8.245255s | nms: 0.030482s
# spend: 0.024461s | spend: 0.005941s | Complete: 109 | avg spend_time: 8.332339s | detect: 8.240721s | nms: 0.019485s
# spend: 0.023300s | spend: 0.005807s | Complete: 110 | avg spend_time: 8.331537s | detect: 8.228175s | nms: 0.012637s
# spend: 0.024190s | spend: 0.005698s | Complete: 111 | avg spend_time: 8.330844s | detect: 8.231860s | nms: 0.019410s
# spend: 0.024007s | spend: 0.005837s | Complete: 112 | avg spend_time: 8.330162s | detect: 8.228416s | nms: 0.022576s
# spend: 0.023027s | spend: 0.006260s | Complete: 113 | avg spend_time: 8.330586s | detect: 8.361143s | nms: 0.014786s
# spend: 0.022275s | spend: 0.006160s | Complete: 114 | avg spend_time: 8.329583s | detect: 8.209118s | nms: 0.004381s
# spend: 0.024156s | spend: 0.006125s | Complete: 115 | avg spend_time: 8.328883s | detect: 8.227407s | nms: 0.018437s
# spend: 0.023746s | spend: 0.006132s | Complete: 116 | avg spend_time: 8.328323s | detect: 8.236051s | nms: 0.024217s
# spend: 0.023580s | spend: 0.005972s | Complete: 117 | avg spend_time: 8.327784s | detect: 8.243156s | nms: 0.018887s
# spend: 0.022910s | spend: 0.006110s | Complete: 118 | avg spend_time: 8.327014s | detect: 8.222741s | nms: 0.011108s
# spend: 0.023295s | spend: 0.006168s | Complete: 119 | avg spend_time: 8.326365s | detect: 8.231342s | nms: 0.015428s
# spend: 0.024235s | spend: 0.005936s | Complete: 120 | avg spend_time: 8.325823s | detect: 8.234865s | nms: 0.022881s
# spend: 0.023925s | spend: 0.006492s | Complete: 121 | avg spend_time: 8.325501s | detect: 8.259437s | nms: 0.023719s
# spend: 0.024260s | spend: 0.005930s | Complete: 122 | avg spend_time: 8.325022s | detect: 8.239287s | nms: 0.024338s
# spend: 0.023105s | spend: 0.005759s | Complete: 123 | avg spend_time: 8.324292s | detect: 8.220123s | nms: 0.011782s
# spend: 0.024981s | spend: 0.005991s | Complete: 124 | avg spend_time: 8.323795s | detect: 8.234873s | nms: 0.024335s
# spend: 0.022890s | spend: 0.006483s | Complete: 125 | avg spend_time: 8.323269s | detect: 8.241727s | nms: 0.013377s
# spend: 0.023435s | spend: 0.005774s | Complete: 126 | avg spend_time: 8.322811s | detect: 8.245254s | nms: 0.017154s
# spend: 0.023737s | spend: 0.005859s | Complete: 127 | avg spend_time: 8.322284s | detect: 8.235524s | nms: 0.017377s
# spend: 0.022292s | spend: 0.005777s | Complete: 128 | avg spend_time: 8.322426s | detect: 8.334707s | nms: 0.004105s
# spend: 0.022894s | spend: 0.006321s | Complete: 129 | avg spend_time: 8.322170s | detect: 8.271985s | nms: 0.014192s
# spend: 0.023156s | spend: 0.005987s | Complete: 130 | avg spend_time: 8.321530s | detect: 8.225230s | nms: 0.010694s
# spend: 0.023820s | spend: 0.005988s | Complete: 131 | avg spend_time: 8.321145s | detect: 8.243651s | nms: 0.024005s
# spend: 0.023004s | spend: 0.005923s | Complete: 132 | avg spend_time: 8.320557s | detect: 8.229563s | nms: 0.011190s
# spend: 0.023203s | spend: 0.006114s | Complete: 133 | avg spend_time: 8.320166s | detect: 8.253268s | nms: 0.012250s
# spend: 0.022910s | spend: 0.005926s | Complete: 134 | avg spend_time: 8.319643s | detect: 8.237465s | nms: 0.009796s
# spend: 0.023941s | spend: 0.006049s | Complete: 135 | avg spend_time: 8.319185s | detect: 8.236396s | nms: 0.018422s
# spend: 0.024055s | spend: 0.005970s | Complete: 136 | avg spend_time: 8.318795s | detect: 8.243890s | nms: 0.019294s
# spend: 0.022884s | spend: 0.005819s | Complete: 137 | avg spend_time: 8.318297s | detect: 8.239755s | nms: 0.007991s
# spend: 0.022951s | spend: 0.006061s | Complete: 138 | avg spend_time: 8.317829s | detect: 8.239261s | nms: 0.011450s
# spend: 0.023877s | spend: 0.006081s | Complete: 139 | avg spend_time: 8.317397s | detect: 8.232917s | nms: 0.021630s
# spend: 0.023318s | spend: 0.005802s | Complete: 140 | avg spend_time: 8.316811s | detect: 8.220025s | nms: 0.012238s
# spend: 0.024093s | spend: 0.005888s | Complete: 141 | avg spend_time: 8.316386s | detect: 8.238855s | nms: 0.015069s
# spend: 0.023704s | spend: 0.006115s | Complete: 142 | avg spend_time: 8.315989s | detect: 8.236623s | nms: 0.020174s
# spend: 0.023159s | spend: 0.005912s | Complete: 143 | avg spend_time: 8.316048s | detect: 8.312254s | nms: 0.009780s
# spend: 0.023237s | spend: 0.006099s | Complete: 144 | avg spend_time: 8.315482s | detect: 8.217835s | nms: 0.013611s
# spend: 0.024386s | spend: 0.005918s | Complete: 145 | avg spend_time: 8.315282s | detect: 8.253777s | nms: 0.029310s
# spend: 0.025201s | spend: 0.006074s | Complete: 146 | avg spend_time: 8.315194s | detect: 8.256093s | nms: 0.042744s
# spend: 0.023588s | spend: 0.006065s | Complete: 147 | avg spend_time: 8.314724s | detect: 8.230277s | nms: 0.012938s
# spend: 0.023431s | spend: 0.005970s | Complete: 148 | avg spend_time: 8.314237s | detect: 8.224923s | nms: 0.014693s
# spend: 0.023311s | spend: 0.005753s | Complete: 149 | avg spend_time: 8.313781s | detect: 8.230663s | nms: 0.012851s
# spend: 0.023717s | spend: 0.006180s | Complete: 150 | avg spend_time: 8.313462s | detect: 8.244117s | nms: 0.018766s
# spend: 0.023692s | spend: 0.005945s | Complete: 151 | avg spend_time: 8.313023s | detect: 8.228506s | nms: 0.015794s
# spend: 0.023294s | spend: 0.005934s | Complete: 152 | avg spend_time: 8.312562s | detect: 8.225157s | nms: 0.014549s
# spend: 0.023642s | spend: 0.006278s | Complete: 153 | avg spend_time: 8.312190s | detect: 8.238621s | nms: 0.014006s
# spend: 0.023239s | spend: 0.006227s | Complete: 154 | avg spend_time: 8.311718s | detect: 8.220944s | nms: 0.015405s
# spend: 0.024052s | spend: 0.006247s | Complete: 155 | avg spend_time: 8.311331s | detect: 8.225438s | nms: 0.023152s
# spend: 0.023690s | spend: 0.006163s | Complete: 156 | avg spend_time: 8.310922s | detect: 8.224666s | nms: 0.019683s
# spend: 0.022754s | spend: 0.006018s | Complete: 157 | avg spend_time: 8.311319s | detect: 8.361653s | nms: 0.009884s
# spend: 0.024241s | spend: 0.005649s | Complete: 158 | avg spend_time: 8.311073s | detect: 8.245406s | nms: 0.023943s
# spend: 0.023242s | spend: 0.006258s | Complete: 159 | avg spend_time: 8.310739s | detect: 8.246125s | nms: 0.009129s
# spend: 0.023394s | spend: 0.005919s | Complete: 160 | avg spend_time: 8.310398s | detect: 8.239674s | nms: 0.013481s
# spend: 0.022690s | spend: 0.006670s | Complete: 161 | avg spend_time: 8.310191s | detect: 8.263515s | nms: 0.011086s
# spend: 0.023762s | spend: 0.006158s | Complete: 162 | avg spend_time: 8.309991s | detect: 8.258804s | nms: 0.016313s
# spend: 0.024202s | spend: 0.005951s | Complete: 163 | avg spend_time: 8.309654s | detect: 8.230627s | nms: 0.021143s
# spend: 0.023427s | spend: 0.005568s | Complete: 164 | avg spend_time: 8.309225s | detect: 8.222922s | nms: 0.013418s
# spend: 0.023527s | spend: 0.006115s | Complete: 165 | avg spend_time: 8.308996s | detect: 8.257672s | nms: 0.011289s
# spend: 0.024091s | spend: 0.006169s | Complete: 166 | avg spend_time: 8.308818s | detect: 8.254732s | nms: 0.021269s

# %%
# import threading
# class saveImage(threading.Thread):
#    def __init__(self, path, image):
#         super().__init__()
#         self.path = path
#         self.image = image
    
#     def run(self):
#         cv2.imwrite(self.path, self.image)

# for i, (image_orig, boxes) in enumerate(zip(image_list, detections_result)):
#     image = image_orig.copy()
#     for box in boxes:
#         cv2.putText(image, "%s %f%%" % (LABEL_LIST[box.cls], box.conf), (box.x1, box.y1-10), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255))
#         cv2.rectangle(image, (box.x1, box.y1), (box.x2, box.y2), (0, 0, 255), 3)
    
#     saveImage("detect/image-%d.png" % (i), image).start()
